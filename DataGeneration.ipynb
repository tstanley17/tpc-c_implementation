# %%
import pandas as pd
from faker import Faker

# %%
import random

# %%
from collections import defaultdict 
from sqlalchemy import create_engine
fake = Faker()
fake_warehouse = defaultdict(list)
i = 0

# %%
from faker.providers import color
fake.add_provider(color)

# %%
engine = create_engine("mysql://root:Fb8kq6@localhost/tpccmodel",echo = True)

# %%
fake_warehouse = defaultdict(list)

# %%
for _ in range(5):
    fake_warehouse["W_ID"].append( i )
    fake_warehouse["W_NAME"].append((lambda x: x[:10] if len(x)>10 else x)(fake.color_name()))
    fake_warehouse["W_STREET_1"].append((lambda x: x[:20] if len(x)>20 else x)(fake.street_address()))
    fake_warehouse["W_STREET_2"].append((lambda x: x[:20] if len(x)>20 else x)(fake.street_address()))
    fake_warehouse["W_CITY"].append((lambda x: x[:20] if len(x)>20 else x)(fake.city()))
    fake_warehouse["W_STATE"].append(fake.country_code())
    fake_warehouse["W_ZIP"].append(fake.postcode())
    fake_warehouse["W_TAX"].append(float(fake.numerify(text = ".####")))
    fake_warehouse["W_YTD"].append(float(fake.numerify(text = "%#########.##")))
    i+=1

# %%
df_fake_warehouse = pd.DataFrame(fake_warehouse)

# %%
df_fake_warehouse
# Out:
#    W_ID      W_NAME            W_STREET_1            W_STREET_2  \
# 0     0  PowderBlue  6329 Heather Trail S   75094 Jones Harbors
# 1     1      Yellow    277 Patrick Canyon  796 Darlene Cape Sui
# 2     2     HotPink  0776 Michael Roads A        0887 Eric Ways
# 3     3     Fuchsia  782 Brown Mountain A     766 Daniel Avenue
# 4     4        Blue          505 Ray Loop  9327 Gary Route Apt.
#
#              W_CITY W_STATE  W_ZIP   W_TAX         W_YTD
# 0         Amandaton      PW  66896  0.8763  7.720845e+09
# 1         West Carl      FM  17152  0.0919  8.224808e+09
# 2        Lake Larry      MX  63669  0.1507  7.312258e+09
# 3  East Christopher      BS  36962  0.2458  6.486740e+09
# 4         New Bobby      CH  29342  0.9952  5.853000e+09

# %%
df_fake_warehouse.to_sql('warehouse', if_exists='append',con=engine, index=False )
# Out:
# 2021-12-01 12:07:33,511 INFO sqlalchemy.engine.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2021-12-01 12:07:33,513 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-12-01 12:07:33,518 INFO sqlalchemy.engine.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2021-12-01 12:07:33,519 INFO sqlalchemy.engine.Engine [generated in 0.00127s] ()
# 2021-12-01 12:07:33,524 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2021-12-01 12:07:33,527 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2021-12-01 12:07:33,531 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %s AND table_name = %s
# 2021-12-01 12:07:33,533 INFO sqlalchemy.engine.Engine [generated in 0.00127s] ('testing', 'warehouse')
# 2021-12-01 12:07:33,539 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# ...

# %%
fake_district = defaultdict(list)

# %%
i = 0

# %%
# Out:
# 'lime'

# %%
for v in fake_warehouse["W_ID"]:
    for _ in range(10):
        fake_district["D_ID"].append( i )
        fake_district["D_W_ID"].append(v)
        fake_district["D_NAME"].append((lambda x: x[:10] if len(x)>10 else x)(fake.color_name()))
        fake_district["D_STREET_1"].append((lambda x: x[:20] if len(x)>20 else x)(fake.street_address()))
        fake_district["D_STREET_2"].append((lambda x: x[:20] if len(x)>20 else x)(fake.street_address()))
        fake_district["D_CITY"].append((lambda x: x[:20] if len(x)>20 else x)(fake.city()))
        fake_district["D_STATE"].append(fake.country_code())
        fake_district["D_ZIP"].append(fake.postcode())
        fake_district["D_TAX"].append(fake.pyfloat( min_value=0.0,max_value=1)/5)
        fake_district["D_YTD"].append(30000.00)
        fake_district["D_NEXT_O_ID"].append(3001)
        i+=1

# %%
df_fake_district = pd.DataFrame(fake_district)

# %%
df_fake_district
# Out:
#     D_ID  D_W_ID      D_NAME            D_STREET_1            D_STREET_2  \
# 0      0       0     OldLace  1875 Gonzalez Summit  573 Michelle Islands
# 1      1       0       Olive       5519 Smith Wall  058 Cunningham Port
# 2      2       0      Violet         193 Mark Club  19968 Mahoney Meadow
# 3      3       0   SlateGray  41310 Gonzalez Ridge    39844 Conner River
# 4      4       0     OldLace       345 Harris Isle  32079 Jeffrey Extens
# 5      5       0  LightYello  317 Moss Meadow Suit  834 Coleman Way Apt.
# 6      6       0  SandyBrown  613 Byrd Well Suite   7063 Fuentes Lakes S
# 7      7       0  Aquamarine  46736 Jeffrey Estate    09401 Douglas Well
# 8      8       0   OliveDrab      65292 Shawn Flat        2032 Ross Road
# 9      9       0        Aqua  9820 Adams Tunnel Su  8177 Michael Plains
# 10    10       1      Orchid  435 Alvarado Prairie  200 Cruz Mills Apt.
# 11    11       1       Linen  191 Smith Lock Apt.   63119 Arthur Plaza S
# ...

# %%
df_fake_district.to_sql('district', if_exists='append',con=engine, index=False )
# Out:
# 2021-12-01 12:10:29,877 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %s AND table_name = %s
# 2021-12-01 12:10:29,880 INFO sqlalchemy.engine.Engine [cached since 176.3s ago] ('testing', 'district')
# 2021-12-01 12:10:29,890 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-12-01 12:10:29,899 INFO sqlalchemy.engine.Engine INSERT INTO district (`D_ID`, `D_W_ID`, `D_NAME`, `D_STREET_1`, `D_STREET_2`, `D_CITY`, `D_STATE`, `D_ZIP`, `D_TAX`, `D_YTD`, `D_NEXT_O_ID`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ...

# %%
fake_customer = defaultdict(list)
i=0

# %%
def getDfValue(df,keyname, keyvalue,column):
    return df.loc[df[keyname]==keyvalue].iloc[0][column]

# %%
def getDatetime():
    date = fake.date_time()
    date = date.timetuple()
    return f"{date[0]}:{date[1]}:{date[2]} {date[3]}:{date[4]}:{date[5]}"

# %%
getDatetime()
# Out:
# '1993:6:23 21:27:40'

# %%
import random

# %%
("GC","BC")[random.randint(0,1)]
# Out:
# 'GC'

# %%
for i in range(5):
    print(fake.lexify(text = "".join("?"*random.randint(10,20))))
# Out:
# KWTXTxKkXChYkbLOp
# zLmCszgcZLsu
# ycBrjGrVsKm
# noAUVwJQikA
# xBdBTLNthZsd

# %%
for v in fake_district["D_ID"]:
    for _ in range(3000):
        fake_customer["C_ID"].append(i)
        fake_customer["C_D_ID"].append(v)
        fake_customer["C_W_ID"].append(df_fake_district.loc[df_fake_district["D_ID"]==v].iloc[0]["D_W_ID"])
        fake_customer["C_FIRST"].append((lambda x: x[:10] if len(x)>16 else x)(fake.first_name()))
        fake_customer["C_MIDDLE"].append("OE")
        fake_customer["C_LAST"].append((lambda x: x[:10] if len(x)>16 else x)(fake.last_name()))
        fake_customer["C_STREET_1"].append((lambda x: x[:20] if len(x)>20 else x)(fake.street_address()))
        fake_customer["C_STREET_2"].append((lambda x: x[:20] if len(x)>20 else x)(fake.street_address()))
        fake_customer["C_CITY"].append((lambda x: x[:20] if len(x)>20 else x)(fake.city()))
        fake_customer["C_STATE"].append(fake.country_code())
        fake_customer["C_ZIP"].append(fake.postcode())
        fake_customer["C_PHONE"].append(fake.random_number(digits = 16))
        fake_customer["C_SINCE"].append(getDatetime())
        fake_customer["C_CREDIT"].append(("GC", "BC")[random.randint(0,1)])
        fake_customer["C_CREDIT_LIM"].append(float(50000))
        fake_customer["C_DISCOUNT"].append(fake.pyfloat(max_value=1,positive=True)/2)
        fake_customer["C_BALANCE"].append(-10.00)
        fake_customer["C_YTD_PAYMENT"].append(10.00)
        fake_customer["C_PAYMENT_CNT"].append(1)
        fake_customer["C_DELIVERY_CNT"].append(0)
        fake_customer["C_DATA"].append("".join(fake.random_letters(length=random.randint(300,500))))
        i+=1

# %%
df_fake_customer = pd.DataFrame(fake_customer)

# %%
df_fake_customer
# Out:
#           C_ID  C_D_ID  C_W_ID    C_FIRST C_MIDDLE    C_LAST  \
# 0            4       0       0   Benjamin       OE      Owen
# 1            5       0       0    Diamond       OE      Khan
# 2            6       0       0     Andrea       OE      Moon
# 3            7       0       0    Colleen       OE     Casey
# 4            8       0       0    Madison       OE     Patel
# ...        ...     ...     ...        ...      ...       ...
# 149995  149999      49       4     Dennis       OE     White
# 149996  150000      49       4  Elizabeth       OE     Hodge
# 149997  150001      49       4     Steven       OE     Jones
# 149998  150002      49       4     Joseph       OE     Burns
# 149999  150003      49       4      Julia       OE  Cummings
#
#                   C_STREET_1            C_STREET_2          C_CITY C_STATE  \
# 0       647 Cynthia Port Sui  1576 Mcpherson Forks       Joanhaven      BD
# 1       43732 Castillo Avenu  309 Johns Coves Apt.      Davishaven      SL
# ...

# %%
df_fake_customer.to_sql('customer',if_exists='append', con=engine, index=False)
# Out:
# 2021-12-01 12:22:18,035 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %s AND table_name = %s
# 2021-12-01 12:22:18,037 INFO sqlalchemy.engine.Engine [cached since 884.5s ago] ('testing', 'customer')
# 2021-12-01 12:22:18,375 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-12-01 12:22:24,514 INFO sqlalchemy.engine.Engine INSERT INTO customer (`C_ID`, `C_D_ID`, `C_W_ID`, `C_FIRST`, `C_MIDDLE`, `C_LAST`, `C_STREET_1`, `C_STREET_2`, `C_CITY`, `C_STATE`, `C_ZIP`, `C_PHONE`, `C_SINCE`, `C_CREDIT`, `C_CREDIT_LIM`, `C_DISCOUNT`, `C_BALANCE`, `C_YTD_PAYMENT`, `C_PAYMENT_CNT`, `C_DELIVERY_CNT`, `C_DATA`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ...

# %%
engine.dispose()

# %%
fake_item = defaultdict(list)

# %%
del fake_item
fake_item = defaultdict(list)

# %%
for i in range(100000):
    fake_item["I_ID"].append(i)
    fake_item["I_IM_ID"].append(random.randint(1,10000))
    fake_item["I_NAME"].append((lambda x: x[:24] if len(x)>24 else x)(fake.name()))
    fake_item["I_PRICE"].append(round(random.uniform(1,100),2))
    fake_item["I_DATA"].append("".join(fake.random_letters(length=random.randint(26,50))))

# %%
df_fake_item = pd.DataFrame(fake_item)

# %%
df_fake_item
# Out:
#         I_ID  I_IM_ID             I_NAME  I_PRICE  \
# 0          0       74      Jake Melendez    86.39
# 1          1     2607       Jamie Hudson    23.65
# 2          2      417       Kendra Evans    62.73
# 3          3     1309        John Deleon    54.49
# 4          4     1654         Terry Sims    87.85
# ...      ...      ...                ...      ...
# 99995  99995     3430       Thomas Riley    67.97
# 99996  99996     5394   Katherine Austin    55.03
# 99997  99997     1531     Kayla Reynolds    34.75
# 99998  99998     4053         Luke Scott    31.34
# 99999  99999     9877  Jennifer Martinez    48.65
#
#                                                 I_DATA
# 0                       acdcMLbAmEHfFZCcHLLurjcSZwLmaT
# 1                        AoVrIHYrWYdFsFEnQtiiLDpspWXRO
# 2                         ecaMWzWNpgUbeqiecvfiKrqRwDRt
# 3         EtcfUlzhpoSYTYrdGJaXNXNvJpgHfRelAaoGspVrBsuu
# 4        oBVIjOSzSouHQSSmxbJoDMdGpnhVZtqNpxswUeRXTNLkt
# ...

# %%
engine = create_engine("mysql://root:Fb8kq6@localhost/tpccmodel",echo = True)

# %%
df_fake_item.to_sql('item',if_exists='append', con=engine, index=False)
# Out:
# 2021-12-01 13:01:00,450 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %s AND table_name = %s
# 2021-12-01 13:01:00,452 INFO sqlalchemy.engine.Engine [cached since 134.3s ago] ('tpccmodel', 'item')
# 2021-12-01 13:01:00,508 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-12-01 13:01:02,516 INFO sqlalchemy.engine.Engine INSERT INTO item (`I_ID`, `I_IM_ID`, `I_NAME`, `I_PRICE`, `I_DATA`) VALUES (%s, %s, %s, %s, %s)
# ...

# %%
fake_stock = defaultdict(list)

# %%
for wid in fake_warehouse["W_ID"]:
    for i in range(100000):
        fake_stock["S_I_ID"].append(i)
        fake_stock["S_W_ID"].append(wid)
        fake_stock["S_QUANTITY"].append(random.randint(10,100))
        fake_stock["S_DIST_01"].append("".join(fake.random_letters(length = 24)))
        fake_stock["S_DIST_02"].append("".join(fake.random_letters(length = 24)))
        fake_stock["S_DIST_03"].append("".join(fake.random_letters(length = 24)))
        fake_stock["S_DIST_04"].append("".join(fake.random_letters(length = 24)))
        fake_stock["S_DIST_05"].append("".join(fake.random_letters(length = 24)))
        fake_stock["S_DIST_06"].append("".join(fake.random_letters(length = 24)))
        fake_stock["S_DIST_07"].append("".join(fake.random_letters(length = 24)))
        fake_stock["S_DIST_08"].append("".join(fake.random_letters(length = 24)))
        fake_stock["S_DIST_09"].append("".join(fake.random_letters(length = 24)))
        fake_stock["S_DIST_10"].append("".join(fake.random_letters(length = 24)))
        fake_stock["S_YTD"].append(0)
        fake_stock["S_ORDER_CNT"].append(0)
        fake_stock["S_REMOTE_CNT"].append(0)
        fake_stock["S_DATA"].append("".join(fake.random_letters(length=random.randint(26,50))))

# %%
df_fake_stock = pd.DataFrame(fake_stock)
df_fake_stock.to_sql('stock',if_exists='append', con=engine, index=False)
# Out:
# 2021-12-01 13:16:55,627 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %s AND table_name = %s
# 2021-12-01 13:16:55,628 INFO sqlalchemy.engine.Engine [cached since 1089s ago] ('tpccmodel', 'stock')
# 2021-12-01 13:16:56,694 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-12-01 13:17:13,798 INFO sqlalchemy.engine.Engine INSERT INTO stock (`S_I_ID`, `S_W_ID`, `S_QUANTITY`, `S_DIST_01`, `S_DIST_02`, `S_DIST_03`, `S_DIST_04`, `S_DIST_05`, `S_DIST_06`, `S_DIST_07`, `S_DIST_08`, `S_DIST_09`, `S_DIST_10`, `S_YTD`, `S_ORDER_CNT`, `S_REMOTE_CNT`, `S_DATA`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
# ...

# %%
fake_history = defaultdict(list)

# %%
import datetime

# %%
print(datetime.datetime.now())
# Out:
# 2021-12-01 14:12:55.426242

# %%
for row in df_fake_customer[['C_ID','C_W_ID', 'C_D_ID']].itertuples(index = False):
    fake_history["H_C_ID"].append(row[0])
    fake_history["H_C_D_ID"].append(row[2])
    fake_history["H_C_W_ID"].append(row[1])
    fake_history["H_DATE"].append(datetime.datetime.now())
    fake_history["H_AMOUNT"].append(10.00)
    fake_history["H_DATA"].append("".join(fake.random_letters(length=random.randint(12,24))))

# %%
df_fake_history = pd.DataFrame(fake_history)

# %%
df_fake_history
# Out:
#         H_C_ID  H_C_D_ID  H_C_W_ID                     H_DATE  H_AMOUNT  \
# 0            4         0         0 2021-12-01 15:28:02.401278      10.0
# 1            5         0         0 2021-12-01 15:28:02.401278      10.0
# 2            6         0         0 2021-12-01 15:28:02.401278      10.0
# 3            7         0         0 2021-12-01 15:28:02.401278      10.0
# 4            8         0         0 2021-12-01 15:28:02.401278      10.0
# ...        ...       ...       ...                        ...       ...
# 149995  149999        49         4 2021-12-01 15:28:05.830888      10.0
# 149996  150000        49         4 2021-12-01 15:28:05.830888      10.0
# 149997  150001        49         4 2021-12-01 15:28:05.830888      10.0
# 149998  150002        49         4 2021-12-01 15:28:05.830888      10.0
# 149999  150003        49         4 2021-12-01 15:28:05.830888      10.0
#
#                           H_DATA
# 0       lMJZReVgRQUfHVUeDmLmqSFk
# 1           XXXlptJuLvSvUbHyNcAy
# ...

# %%
del fake_orders
fake_orders = defaultdict(list)

# %%
import numpy as np
a = np.arange(4,3004)
np.random.shuffle(a)
a
# Out:
# array([2673, 2405, 2170, ..., 1031, 1504,  852])

# %%
for row in df_fake_district[["D_ID","D_W_ID"]].itertuples():
    print(row)

# %%
row = df_fake_customer.loc[df_fake_customer.C_ID == 10]

# %%
print(row)
# Out:
#    C_ID  C_D_ID  C_W_ID   C_FIRST C_MIDDLE  C_LAST            C_STREET_1  \
# 6    10       0       0  Samantha       OE  Krause  5844 Bryant Port Sui
#
#              C_STREET_2             C_CITY C_STATE  ...           C_PHONE  \
# 6  793 Mahoney Knoll Ap  Port Williamshire      TN  ...  3734698441924132
#
#               C_SINCE C_CREDIT C_CREDIT_LIM  C_DISCOUNT  C_BALANCE  \
# 6  1975:4:13 22:44:10       BC      50000.0    0.096707      -10.0
#
#    C_YTD_PAYMENT  C_PAYMENT_CNT  C_DELIVERY_CNT  \
# 6           10.0              1               0
#
#                                               C_DATA
# 6  jpJVldeJcQDMDjADQdvAsLyVgqmuKQVkyxgUkIIhJCsvWM...
#
# [1 rows x 21 columns]

# %%
for i in range(3000):
    c_ID = a[i]
    row = df_fake_customer.loc[df_fake_customer.C_ID == c_ID]
    fake_orders["O_ID"].append(i)
    fake_orders["O_C_ID"].append(c_ID)

    fake_orders["O_D_ID"].append(row.iat[0,1])
    fake_orders["O_W_ID"].append(row.iat[0,2])
    fake_orders["O_ENTRY_D"].append(datetime.datetime.now())
    fake_orders["O_CARRIER_ID"].append(random.randint(1,10))
    fake_orders["O_OL_CNT"].append(random.randint(5,15))
    fake_orders["O_ALL_LOCAL"].append(1)

# %%
df_fake_orders = pd.DataFrame(fake_orders)

# %%
df_fake_orders
# Out:
#       O_ID  O_C_ID  O_D_ID  O_W_ID                  O_ENTRY_D  O_CARRIER_ID  \
# 0        0    2673       0       0 2021-12-01 15:26:11.509202            10
# 1        1    2405       0       0 2021-12-01 15:26:11.511196             9
# 2        2    2170       0       0 2021-12-01 15:26:11.512194             1
# 3        3     674       0       0 2021-12-01 15:26:11.514195             5
# 4        4     653       0       0 2021-12-01 15:26:11.517181             9
# ...    ...     ...     ...     ...                        ...           ...
# 2995  2995     270       0       0 2021-12-01 15:26:14.925998             8
# 2996  2996    2778       0       0 2021-12-01 15:26:14.926995            10
# 2997  2997    1031       0       0 2021-12-01 15:26:14.927993             6
# 2998  2998    1504       0       0 2021-12-01 15:26:14.927993            10
# 2999  2999     852       0       0 2021-12-01 15:26:14.928990             1
#
#       O_OL_CNT  O_ALL_LOCAL
# ...

# %%
df_fake_history.to_sql('history',if_exists='append', con=engine, index=False)
# Out:
# 2021-12-01 15:28:25,595 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %s AND table_name = %s
# 2021-12-01 15:28:25,596 INFO sqlalchemy.engine.Engine [cached since 8979s ago] ('tpccmodel', 'history')
# 2021-12-01 15:28:25,799 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-12-01 15:28:27,527 INFO sqlalchemy.engine.Engine INSERT INTO history (`H_C_ID`, `H_C_D_ID`, `H_C_W_ID`, `H_DATE`, `H_AMOUNT`, `H_DATA`) VALUES (%s, %s, %s, %s, %s, %s)
# ...

# %%
df_fake_orders.to_sql('orders',if_exists='append', con=engine, index=False)
# Out:
# 2021-12-01 15:29:09,392 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %s AND table_name = %s
# 2021-12-01 15:29:09,393 INFO sqlalchemy.engine.Engine [cached since 9023s ago] ('tpccmodel', 'orders')
# 2021-12-01 15:29:09,407 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-12-01 15:29:09,446 INFO sqlalchemy.engine.Engine INSERT INTO orders (`O_ID`, `O_C_ID`, `O_D_ID`, `O_W_ID`, `O_ENTRY_D`, `O_CARRIER_ID`, `O_OL_CNT`, `O_ALL_LOCAL`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
# ...

# %%
engine.dispose()
